# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df  = pd.read_csv(r"C:\Users\Acer\Downloads\netflix.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['country']
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe(include = 'object')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.keys()
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df['country'].unique()
# Out:
# array(['United States', 'South Africa', nan, 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
#        'Australia, United States', 'Argentina, Venezuela',
# ...

# %%
df.drop('description' , axis = 1 , inplace = True )

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
a = df['country'][:10]

# %%
a.reset_index()
# Out:
#    index                                            country
# 0      0                                      United States
# 1      1                                       South Africa
# 2      2                                                NaN
# 3      3                                                NaN
# 4      4                                              India
# 5      5                                                NaN
# 6      6                                                NaN
# 7      7  United States, Ghana, Burkina Faso, United Kin...
# 8      8                                     United Kingdom
# 9      9                                      United States

# %%
pd.DataFrame(a)
# Out:
#                                              country
# 0                                      United States
# 1                                       South Africa
# 2                                                NaN
# 3                                                NaN
# 4                                              India
# 5                                                NaN
# 6                                                NaN
# 7  United States, Ghana, Burkina Faso, United Kin...
# 8                                     United Kingdom
# 9                                      United States

# %%
a
# Out:
# 0                                        United States
# 1                                         South Africa
# 2                                                  NaN
# 3                                                  NaN
# 4                                                India
# 5                                                  NaN
# 6                                                  NaN
# 7    United States, Ghana, Burkina Faso, United Kin...
# 8                                       United Kingdom
# 9                                        United States
# Name: country, dtype: object

# %%
df.shape[1]
# Out:
# 11

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df.set_index('country')
# Out:
#               show_id     type                  title         director  \
# country
# United States      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# South Africa       s2  TV Show          Blood & Water              NaN
# NaN                s3  TV Show              Ganglands  Julien Leclercq
# NaN                s4  TV Show  Jailbirds New Orleans              NaN
# India              s5  TV Show           Kota Factory              NaN
# ...               ...      ...                    ...              ...
# United States   s8803    Movie                 Zodiac    David Fincher
# NaN             s8804  TV Show            Zombie Dumb              NaN
# United States   s8805    Movie             Zombieland  Ruben Fleischer
# United States   s8806    Movie                   Zoom     Peter Hewitt
# India           s8807    Movie                 Zubaan      Mozez Singh
#
#                                                             cast  \
# country
# ...

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.iloc[0:5 , 1:7]
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added
# 0  September 25, 2021
# 1  September 24, 2021
# 2  September 24, 2021
# 3  September 24, 2021
# 4  September 24, 2021

# %%
df.loc[0:5 , ['country' , 'type']]
# Out:
#          country     type
# 0  United States    Movie
# 1   South Africa  TV Show
# 2            NaN  TV Show
# 3            NaN  TV Show
# 4          India  TV Show
# 5            NaN  TV Show

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.sort_values(['director'])
# Out:
#      show_id     type               title         director  \
# 6078   s6079    Movie           Abhinetri      A. L. Vijay
# 3537   s3538    Movie            Watchman      A. L. Vijay
# 2389   s2390    Movie          Asura Guru     A. Raajdheep
# 5549   s5550    Movie           Salaakhen        A. Salaam
# 4681   s4682    Movie              Spyder  A.R. Murugadoss
# ...      ...      ...                 ...              ...
# 8795   s8796  TV Show     Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show          Yunus Emre              NaN
# 8797   s8798  TV Show           Zak Storm              NaN
# 8800   s8801  TV Show  Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show         Zombie Dumb              NaN
#
#                                                    cast  \
# 6078  Tamannaah Bhatia, Prabhu Deva, Sonu Sood, Sapt...
# 3537  G.V. Prakash Kumar, Samyuktha Hegde, Suman, Ra...
# 2389  Vikram Prabhu, Subbaraju, Mahima Nambiar, Yogi...
# ...

# %%
df.sort_values('director')
# Out:
#      show_id     type               title         director  \
# 6078   s6079    Movie           Abhinetri      A. L. Vijay
# 3537   s3538    Movie            Watchman      A. L. Vijay
# 2389   s2390    Movie          Asura Guru     A. Raajdheep
# 5549   s5550    Movie           Salaakhen        A. Salaam
# 4681   s4682    Movie              Spyder  A.R. Murugadoss
# ...      ...      ...                 ...              ...
# 8795   s8796  TV Show     Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show          Yunus Emre              NaN
# 8797   s8798  TV Show           Zak Storm              NaN
# 8800   s8801  TV Show  Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show         Zombie Dumb              NaN
#
#                                                    cast  \
# 6078  Tamannaah Bhatia, Prabhu Deva, Sonu Sood, Sapt...
# 3537  G.V. Prakash Kumar, Samyuktha Hegde, Suman, Ra...
# 2389  Vikram Prabhu, Subbaraju, Mahima Nambiar, Yogi...
# ...

# %%
df.loc[df['director'] == 'Christopher Nolan' , 'title']
# Out:
# 340    Inception
# Name: title, dtype: object

# %%
df['director'].value_counts('type')
# Out:
# Rajiv Chilaka                     0.003078
# Raúl Campos, Jan Suter            0.002916
# Marcus Raboy                      0.002592
# Suhas Kadav                       0.002592
# Jay Karas                         0.002268
#                                     ...
# Raymie Muzquiz, Stu Livingston    0.000162
# Joe Menendez                      0.000162
# Eric Bross                        0.000162
# Will Eisenberg                    0.000162
# Mozez Singh                       0.000162
# Name: director, Length: 4528, dtype: float64

# %%
df.groupby('cast')['listed_in'].count().value_counts()
# Out:
# 1     7526
# 2      112
# 3       29
# 4       14
# 6        4
# 5        3
# 19       1
# 7        1
# 10       1
# 14       1
# Name: listed_in, dtype: int64

# %%
df = nf.copy()

# %%
df.fillna('unknown' , inplace = True)

# %%
df = df.assign(cast = df['cast'].str.split(', ')).explode('cast')

# %%
df = df.assign(director = df['director'].str.split(', ')).explode('director')

# %%
df = df.assign(country = df['country'].str.split(', ')).explode('country')

# %%
df = df.assign(listed_in = df['listed_in'].str.split(', ')).explode('listed_in')

# %%
df
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show         Blood & Water          unknown
# 1         s2  TV Show         Blood & Water          unknown
# 1         s2  TV Show         Blood & Water          unknown
# 1         s2  TV Show         Blood & Water          unknown
# ...      ...      ...                   ...              ...
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
#
#                        cast        country          date_added  release_year  \
# 0                   unknown  United States  September 25, 2021          2020
# ...

# %%
Hello All..
for a particular Genre in order to find the most popular Actor/Director ...
 which approach you adopted...
i am not able to get actor based on count..

# %%
a = df.groupby('listed_in')['cast'].value_counts()
cast_list = pd.DataFrame(data=a)
cast_list
# Out:
#                                    cast
# listed_in          cast
# Action & Adventure Luci Christian    28
#                    Hugo Weaving      26
#                    Donnie Yen        25
#                    Andy McAvin       24
#                    James Faulkner    24
# ...                                 ...
# Thrillers          Zoey Deutch        1
#                    Zoë Bell           1
#                    Zulu Adigwe        1
#                    Àlex Monner        1
#                    Álex García        1
#
# [113151 rows x 1 columns]

# %%
# cast_list.loc[cast_list['cast'] == 'Anupam Kher'].head(5)

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show         Blood & Water          unknown
# 1         s2  TV Show         Blood & Water          unknown
# 1         s2  TV Show         Blood & Water          unknown
# 1         s2  TV Show         Blood & Water          unknown
# ...      ...      ...                   ...              ...
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
#
#                        cast        country          date_added  release_year  \
# 0                   unknown  United States  September 25, 2021          2020
# ...

# %%
df.columns = df.columns.str.replace('/' , '_')

# %%
df
# Out:
#      SHOW_ID     TYPE                 TITLE         DIRECTOR  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show         Blood & Water          unknown
# 1         s2  TV Show         Blood & Water          unknown
# 1         s2  TV Show         Blood & Water          unknown
# 1         s2  TV Show         Blood & Water          unknown
# ...      ...      ...                   ...              ...
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
#
#                        CAST        COUNTRY          DATE_ADDED  RELEASE_YEAR  \
# 0                   unknown  United States  September 25, 2021          2020
# ...

# %%
    df.rename(columns = {'show_id' : 'Id' , 'listed_in' : 'genre' } , inplace = True)

# %%
df
# Out:
#          Id     type                 title         director  \
# 0        s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1        s2  TV Show         Blood & Water          unknown
# 1        s2  TV Show         Blood & Water          unknown
# 1        s2  TV Show         Blood & Water          unknown
# 1        s2  TV Show         Blood & Water          unknown
# ...     ...      ...                   ...              ...
# 8806  s8807    Movie                Zubaan      Mozez Singh
# 8806  s8807    Movie                Zubaan      Mozez Singh
# 8806  s8807    Movie                Zubaan      Mozez Singh
# 8806  s8807    Movie                Zubaan      Mozez Singh
# 8806  s8807    Movie                Zubaan      Mozez Singh
#
#                        cast        country          date_added  release_year  \
# 0                   unknown  United States  September 25, 2021          2020
# 1                Ama Qamata   South Africa  September 24, 2021          2021
# ...

# %%
df['country'] = df['country'].replace({'United States' : 'USA'})

# %%
df['country'].tail(50)
# Out:
# 8804      USA
# 8804      USA
# 8804      USA
# 8804      USA
# 8804      USA
# 8804      USA
# 8804      USA
# 8804      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8805      USA
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# 8806    India
# Name: country, dtype: object
